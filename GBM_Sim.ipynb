# %% [markdown]
# GBM Simulation

# %% [markdown]
# $$
# S_{t} = S_{0}e^{\mu t \: + \: \sigma Z_{t}}
# $$

# %% [markdown]
# This is our equation for GBM. We start with log shocks, we assume are iid, using CLT result and Donsker's theorem we can say our sum of (log) shocks converge to Brownian motion, exponentiating we get equation for GBM.

# %%
import pandas as pd
import numpy as np
from numpy import zeros, exp, sqrt
import matplotlib.pyplot as plt


def simulate_path(s0, drift, sigma, total, steps, sims):

    S0 = s0
    r = drift
    T = total
    t = steps
    n = sims


    dt = T/t


    S = zeros((t+1, n))
    S[0] = S0


    for i in range(1, t+1):
        z = np.random.standard_normal(n)
        S[i] = S[i-1] * exp((r - 0.5 * sigma ** 2) * dt + sigma * sqrt(dt) * z)

    return S

# %%
price_path = pd.DataFrame(simulate_path(100, 0.05, 0.20, 1, 10000, 100))
price_path.tail()

plt.figure(figsize=(15, 7))
plt.plot(price_path.iloc[:, :20], alpha=0.5) 
plt.title('Monte Carlo Simulation: 20 Stock Price Paths')
plt.xlabel('Days (Time Steps)')
plt.ylabel('Price')
plt.grid(True)
plt.show()
